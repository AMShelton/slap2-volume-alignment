# %% [markdown]
# # SLAP2 DMD Super-Stack Merge QC
#
# This notebook is for developing and inspecting SLAP2 GUI `*-REFERENCE.tif` DMD stack merging. It supports two workflows:
#
# 1. **Full reference stacks** with SLAP2 JSON metadata preserved in each TIFF page description.
# 2. **Fiji/ImageJ substacks** where the original JSON was stripped. For these, provide the z-start/z-spacing and `dmdPixel2SampleTransform` manually.
#
# The current intended merge is:
#
# ```text
# DMD1 superficial stack + DMD2 deeper stack -> common sample-coordinate super stack
# ```
#
# DMD1 is assumed superficial by default, larger z values are deeper, and the DMD1/DMD2 overlap is inferred from z positions.

# %%
from pathlib import Path
from typing import Optional
import sys
import json
import warnings

from IPython.display import display, HTML


def find_repo_root(start: Optional[Path] = None) -> Path:
    if start is None:
        start = Path.cwd()
    start = start.resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "pyproject.toml").exists() and (candidate / "src" / "slap2_volume_align").exists():
            return candidate
    raise FileNotFoundError(
        "Could not find repo root. Expected pyproject.toml and src/slap2_volume_align.\n"
        f"Started from: {start}"
    )


REPO_ROOT = find_repo_root()
SRC_DIR = REPO_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print(f"Repo root: {REPO_ROOT}")
print(f"Python: {sys.version}")
display(HTML("<style>.container { width:100% !important; }</style>"))
warnings.filterwarnings("default")
# Out:
# Repo root: C:\Users\andrew.shelton\Dropbox\allen institute\Python_Code\ams\morphology\slap2-volume-alignment
# Python: 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import tifffile
import matplotlib.pyplot as plt

from slap2_volume_align.sources.slap2.metadata import (
    read_reference_stack_spec,
    make_manual_reference_stack_spec,
)
from slap2_volume_align.sources.slap2.geometry import (
    compute_output_grid,
    infer_z_overlap_um,
    stack_corners_sample_xy,
)
from slap2_volume_align.sources.slap2.qc import plot_dmd_footprints
from slap2_volume_align.sources.slap2.merge import (
    Slap2MergeConfig,
    merge_dmd_reference_stacks,
    merge_dmd_reference_stack_specs,
)

print("Imports OK")
# Out:
# Imports OK

# %% [markdown]
# ## Configure paths
#
# Use the full original `*-REFERENCE.tif` files when possible. If you are testing with Fiji-created overlap substacks, set `USE_MANUAL_SUBSTACK_METADATA = True`.

# %%
# Full SLAP2 GUI reference stacks. These should preserve per-page JSON metadata.
DMD1_REFERENCE_TIF = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD1-REFERENCE.tif"
)
DMD2_REFERENCE_TIF = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD2-REFERENCE.tif"
)

# Fiji/ImageJ overlap substacks for fast testing. These often lose the SLAP2 JSON metadata.
DMD1_SUBSTACK_TIF = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD1-REFERENCE_substack.tif"
)
DMD2_SUBSTACK_TIF = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD2-REFERENCE_substack.tif"
)

# Set this True for the last-20/first-20 Fiji substacks.
USE_MANUAL_SUBSTACK_METADATA = False

OUT_DIR = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\super_stack_qc"
)
OUT_DIR.mkdir(parents=True, exist_ok=True)

print(OUT_DIR)
# Out:
# \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\super_stack_qc

# %% [markdown]
# ## Manual metadata for Fiji substacks
#
# Fiji-created substacks may replace the SLAP2 JSON `ImageDescription` with ImageJ metadata. In that case, we reconstruct the minimal metadata needed for QC using the known transforms and z ranges.
#
# For your uploaded overlap substacks, the files contained 21 pages. The default values below assume:
#
# - DMD1 substack = full-stack pages 80–100, z = -79.875 to -49.875 µm
# - DMD2 substack = full-stack pages 0–20, z = -60 to -30 µm
#
# Adjust `DMD1_SUBSTACK_Z_START_UM` if your local substack contains exactly 20 pages instead of 21.

# %%
# Transforms from the SLAP2 REFERENCE TIFF JSON.
DMD1_DMD_PIXEL_TO_SAMPLE_TRANSFORM = [
    [0.24907835903790651, -0.0008847190020129167, 0, -1.902316580004602],
    [0.0029171477472943433, 0.25063596511811065, 0, -0.63452150251753014],
    [0, 0, 1, -199.875],
    [0, 0, 0, 1],
]
DMD2_DMD_PIXEL_TO_SAMPLE_TRANSFORM = [
    [0.17567302550946895, 0.1969730316452333, 0, -25.140401931388212],
    [0.16170638488237649, -0.17629969847000435, 0, 52.244553573038651],
    [0, 0, 1, -60],
    [0, 0, 0, 1],
]

DMD1_SUBSTACK_Z_START_UM = -79.875  # last 21 planes: pages 80-100. For last 20 use -78.375.
DMD2_SUBSTACK_Z_START_UM = -60.0
Z_SPACING_UM = 1.5

# %% [markdown]
# ## Inspect TIFF structure and build stack specs

# %%
def inspect_tiff(path: Path, n_desc_chars: int = 500):
    print(f"\n== {path}")
    if not path.exists():
        print("MISSING")
        return
    with tifffile.TiffFile(path) as tif:
        print("n pages:", len(tif.pages))
        print("series:", [(s.shape, s.axes, str(s.dtype)) for s in tif.series])
        print("page 0 shape/dtype:", tif.pages[0].shape, tif.pages[0].dtype)
        desc = tif.pages[0].description or ""
        print(desc[:n_desc_chars])

if USE_MANUAL_SUBSTACK_METADATA:
    DMD1_TIF = DMD1_SUBSTACK_TIF
    DMD2_TIF = DMD2_SUBSTACK_TIF
else:
    DMD1_TIF = DMD1_REFERENCE_TIF
    DMD2_TIF = DMD2_REFERENCE_TIF

inspect_tiff(DMD1_TIF)
inspect_tiff(DMD2_TIF)
# Out:
# == \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD1-REFERENCE.tif
# n pages: 101
# series: [((101, 800, 1280), 'IYX', 'float32')]
# page 0 shape/dtype: (800, 1280) float32
# {"SLAP2ReferenceStackFileVersion":2,"z":-199.875,"channel":1,"acquisitionPathIdx":1,"sourceTifFile":"F:\\slap2Data\\836174_2026-06-17_12-51-17\\ref_volume_20260617_132712_DMD1.tif","dmdPixel2SampleTransform":[[0.24907835903790651,-0.0008847190020129167,0,-1.902316580004602],[0.0029171477472943433,0.25063596511811065,0,-0.63452150251753014],[0,0,1,-199.875],[0,0,0,1]]}
#
# == \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD2-REFERENCE.tif
# n pages: 101
# series: [((101, 800, 1280), 'IYX', 'float32')]
# page 0 shape/dtype: (800, 1280) float32
# {"SLAP2ReferenceStackFileVersion":2,"z":-60,"channel":1,"acquisitionPathIdx":2,"sourceTifFile":"F:\\slap2Data\\836174_2026-06-17_12-51-17\\ref_volume_20260617_132712_DMD2.tif","dmdPixel2SampleTransform":[[0.17567302550946895,0.1969730316452333,0,-25.140401931388212],[0.16170638488237649,-0.17629969847000435,0,52.244553573038651],[0,0,1,-60],[0,0,0,1]]}

# %%
if USE_MANUAL_SUBSTACK_METADATA:
    spec1 = make_manual_reference_stack_spec(
        DMD1_TIF,
        z_start_um=DMD1_SUBSTACK_Z_START_UM,
        z_spacing_um=Z_SPACING_UM,
        transform=DMD1_DMD_PIXEL_TO_SAMPLE_TRANSFORM,
        channel=1,
        acquisition_path_idx=1,
    )
    spec2 = make_manual_reference_stack_spec(
        DMD2_TIF,
        z_start_um=DMD2_SUBSTACK_Z_START_UM,
        z_spacing_um=Z_SPACING_UM,
        transform=DMD2_DMD_PIXEL_TO_SAMPLE_TRANSFORM,
        channel=1,
        acquisition_path_idx=2,
    )
else:
    spec1 = read_reference_stack_spec(DMD1_TIF)
    spec2 = read_reference_stack_spec(DMD2_TIF)

for name, spec in [("DMD1", spec1), ("DMD2", spec2)]:
    print(f"\n{name}")
    print("path:", spec.path)
    print("shape:", spec.n_pages, spec.image_shape, spec.dtype, spec.axes)
    print("channels:", spec.channels)
    print("z range:", spec.z_min_um, spec.z_max_um, "dz:", spec.z_spacing_um)
    print("acq path:", spec.acquisition_path_idx)

print("\nZ overlap (µm):", infer_z_overlap_um(spec1, spec2))
# Out:
# DMD1
# path: \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD1-REFERENCE.tif
# shape: 101 (800, 1280) float32 IYX
# channels: [1]
# z range: -199.875 -49.875 dz: 1.5
# acq path: 1
#
# DMD2
# path: \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\structure_volume_20260617_132712_DMD2-REFERENCE.tif
# shape: 101 (800, 1280) float32 IYX
# channels: [1]
# z range: -60.0 90.0 dz: 1.5
# acq path: 2
#
# Z overlap (µm): (-60.0, -49.875)

# %% [markdown]
# ## Footprint QC
#
# This should resemble the SLAP2 GUI view: DMD1 is approximately axis-aligned, DMD2 is rotated, and the two footprints largely overlap in sample XY.

# %%
XY_RESOLUTION_UM = 0.25 if not USE_MANUAL_SUBSTACK_METADATA else 1.0  # use 1 µm for fast subset tests
Z_RESOLUTION_UM = 1.5

grid = compute_output_grid(
    [spec1, spec2],
    xy_resolution_um=XY_RESOLUTION_UM,
    z_resolution_um=Z_RESOLUTION_UM,
    z_grid="first",
)
print(grid)

fig = plot_dmd_footprints(
    [spec1, spec2],
    labels=["DMD1", "DMD2"],
    grid=grid,
    out_path=OUT_DIR / "notebook_slap2_dmd_footprints_qc.png",
)
plt.show()
# Out:
# SampleGridSpec(x_min_um=-28.0, x_max_um=359.0, y_min_um=-91.0, y_max_um=262.0, z_min_um=-199.875, z_max_um=89.625, xy_resolution_um=0.25, z_resolution_um=1.5, x_size=1549, y_size=1413, z_size=194)

# %% [markdown]
# ## Raw substack projections
#
# This is useful for sanity-checking the overlap substacks before warping.

# %%
def load_small_stack(path: Path) -> np.ndarray:
    arr = tifffile.imread(path)
    if arr.ndim == 2:
        arr = arr[None, ...]
    return arr.astype(np.float32, copy=False)

# This cell is safe for the overlap substacks. Avoid running on full 8-10 GB files unless you intend to load them.
if USE_MANUAL_SUBSTACK_METADATA:
    raw1 = load_small_stack(DMD1_TIF)
    raw2 = load_small_stack(DMD2_TIF)
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    for ax, img, title in zip(axes, [np.nanmax(raw1, axis=0), np.nanmax(raw2, axis=0)], ["DMD1 raw max", "DMD2 raw max"]):
        lo, hi = np.nanpercentile(img, [1, 99.7])
        ax.imshow(img, cmap="gray", vmin=lo, vmax=hi)
        ax.set_title(title)
        ax.axis("off")
    plt.tight_layout()
else:
    print("Skipping raw full-stack load. Set USE_MANUAL_SUBSTACK_METADATA=True for substack projection preview.")
# Out:
# Skipping raw full-stack load. Set USE_MANUAL_SUBSTACK_METADATA=True for substack projection preview.

# %% [markdown]
# ## Merge test
#
# For full reference stacks, start at native-ish `XY_RESOLUTION_UM = 0.25`. For subset tests, use `1.0` µm first for speed. Once the geometry looks right, reduce to `0.5` or `0.25`.

# %%
MERGE_OUT_DIR = OUT_DIR / ("manual_substack_merge" if USE_MANUAL_SUBSTACK_METADATA else "full_reference_merge")
MERGE_OUT_DIR.mkdir(parents=True, exist_ok=True)

config = Slap2MergeConfig(
    dmd1_tif=DMD1_TIF,
    dmd2_tif=DMD2_TIF,
    out_dir=MERGE_OUT_DIR,
    channel=1,
    xy_resolution_um=XY_RESOLUTION_UM,
    z_resolution_um=Z_RESOLUTION_UM,
    z_grid="first",
    z_interp_method="linear",
    output_compression=None,
    fine_register_overlap=True,
    xy_feather_px=32.0,
    z_feather=True,
    write_intermediates=True,
    write_qc_png=True,
)

if USE_MANUAL_SUBSTACK_METADATA:
    summary = merge_dmd_reference_stack_specs(config, spec1, spec2)
else:
    summary = merge_dmd_reference_stacks(config)

print(json.dumps(summary["outputs"], indent=2))
print("Summary JSON written to:", MERGE_OUT_DIR / "slap2_super_stack_merge_summary.json")
# Out:
# C:\Users\andrew.shelton\Dropbox\allen institute\Python_Code\ams\morphology\slap2-volume-alignment\src\slap2_volume_align\sources\slap2\merge.py:203: RuntimeWarning: All-NaN slice encountered
#   return np.nanmax(tmp, axis=0).astype(np.float32)
# C:\Users\andrew.shelton\Anaconda3\lib\site-packages\tifffile\tifffile.py:1784: UserWarning: <tifffile.TiffWriter 'slap2_super_stack_ch1.tif'> writing nonconformant BigTIFF ImageJ
#   warnings.warn(
# C:\Users\andrew.shelton\Anaconda3\lib\site-packages\tifffile\tifffile.py:1784: UserWarning: <tifffile.TiffWriter 'dmd1_warped_ch1.tif'> writing nonconformant BigTIFF ImageJ
#   warnings.warn(
# C:\Users\andrew.shelton\Anaconda3\lib\site-packages\tifffile\tifffile.py:1784: UserWarning: <tifffile.TiffWriter 'dmd2_warped_ch1.tif'> writing nonconformant BigTIFF ImageJ
#   warnings.warn(
# C:\Users\andrew.shelton\Anaconda3\lib\site-packages\tifffile\tifffile.py:1784: UserWarning: <tifffile.TiffWriter 'merge_weights.tif'> writing nonconformant BigTIFF ImageJ
#   warnings.warn(
# {
#   "super_stack": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\slap2_super_stack_ch1.tif",
#   "dmd1_warped": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\dmd1_warped_ch1.tif",
#   "dmd2_warped": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\dmd2_warped_ch1.tif",
#   "weights": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\merge_weights.tif",
#   "footprint_qc_png": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\slap2_dmd_footprints_qc.png",
#   "merge_qc_png": "\\\\allen\\aind\\scratch\\ophys\\Andrew\\VIP_synaptic_dynamics\\iGluSnFR4f+RCaMP3\\836174\\836174_2026-06-17_12-51-17\\slap2\\static_data\\super_stack_qc\\full_reference_merge\\slap2_super_stack_merge_qc.png"
# }
# Summary JSON written to: \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\super_stack_qc\full_reference_merge\slap2_super_stack_merge_summary.json

# %% [markdown]
# ## Inspect merged output lazily

# %%
super_stack_path = Path(summary["outputs"]["super_stack"])
print(super_stack_path)

with tifffile.TiffFile(super_stack_path) as tif:
    print("pages:", len(tif.pages))
    print("series:", [(s.shape, s.axes, str(s.dtype)) for s in tif.series])
    mid = len(tif.pages) // 2
    sample_pages = [0, mid, len(tif.pages) - 1]
    fig, axes = plt.subplots(1, len(sample_pages), figsize=(15, 5))
    for ax, idx in zip(axes, sample_pages):
        img = tif.pages[idx].asarray()
        finite = np.isfinite(img)
        if finite.any():
            lo, hi = np.nanpercentile(img[finite], [1, 99.7])
        else:
            lo, hi = 0, 1
        ax.imshow(img, cmap="gray", vmin=lo, vmax=hi)
        ax.set_title(f"z index {idx}")
        ax.axis("off")
    plt.tight_layout()
# Out:
# \\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\super_stack_qc\full_reference_merge\slap2_super_stack_ch1.tif
# pages: 194
# series: [((194, 1413, 1549), 'ZYX', 'float32')]

# %%
from pathlib import Path
import json
import numpy as np
import tifffile
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

MERGE_DIR = Path(
    r"\\allen\aind\scratch\ophys\Andrew\VIP_synaptic_dynamics\iGluSnFR4f+RCaMP3\836174\836174_2026-06-17_12-51-17\slap2\static_data\super_stack_qc\full_reference_merge"
)

summary_path = MERGE_DIR / "slap2_super_stack_merge_summary.json"
dmd1_path = MERGE_DIR / "dmd1_warped_ch1.tif"
dmd2_path = MERGE_DIR / "dmd2_warped_ch1.tif"

with open(summary_path, "r") as f:
    summary = json.load(f)

z0 = float(summary["output_grid"]["z_min_um"])
dz = float(summary["output_grid"]["z_resolution_um"])
z_overlap = summary["z_overlap_um"]

dmd1 = tifffile.imread(dmd1_path).astype(np.float32)
dmd2 = tifffile.imread(dmd2_path).astype(np.float32)

z_um = z0 + np.arange(dmd1.shape[0]) * dz

# Search somewhat beyond the nominal overlap.
margin_um = 18.0
candidate_idx = np.where(
    (z_um >= z_overlap[0] - margin_um) &
    (z_um <= z_overlap[1] + margin_um)
)[0]

print("candidate planes:")
for idx in candidate_idx:
    print(f"Fiji plane {idx + 1:03d}, zero-index {idx:03d}, z = {z_um[idx]:.3f} um")


def preprocess_for_zcorr(img, highpass_sigma_px=12.0):
    """High-pass and robust-normalize one plane for z similarity."""
    img = img.astype(np.float32, copy=False)
    img = np.nan_to_num(img, nan=0.0, posinf=0.0, neginf=0.0)

    # Remove broad illumination / footprint structure.
    hp = img - gaussian_filter(img, highpass_sigma_px)

    # Robust normalize only nonzero pixels.
    vals = hp[np.isfinite(hp) & (img > 0)]
    if vals.size < 100:
        return hp * 0.0

    med = np.median(vals)
    mad = np.median(np.abs(vals - med)) + 1e-6
    hp = (hp - med) / (1.4826 * mad)

    # Clip bright somata so correlation is not dominated by one saturated cell.
    hp = np.clip(hp, -5, 5)
    return hp.astype(np.float32)


def ncc(a, b, valid_mask):
    vals_a = a[valid_mask]
    vals_b = b[valid_mask]

    if vals_a.size < 1000:
        return np.nan

    vals_a = vals_a - np.mean(vals_a)
    vals_b = vals_b - np.mean(vals_b)

    denom = np.sqrt(np.sum(vals_a ** 2) * np.sum(vals_b ** 2))
    if denom <= 0:
        return np.nan

    return float(np.sum(vals_a * vals_b) / denom)


# Preprocess candidate planes.
dmd1_prep = {}
dmd2_prep = {}
dmd1_valid = {}
dmd2_valid = {}

for idx in candidate_idx:
    dmd1_prep[idx] = preprocess_for_zcorr(dmd1[idx])
    dmd2_prep[idx] = preprocess_for_zcorr(dmd2[idx])

    dmd1_valid[idx] = np.isfinite(dmd1[idx]) & (dmd1[idx] > 0)
    dmd2_valid[idx] = np.isfinite(dmd2[idx]) & (dmd2[idx] > 0)

# Pairwise similarity matrix.
score = np.full((len(candidate_idx), len(candidate_idx)), np.nan, dtype=np.float32)

for ii, i in enumerate(candidate_idx):
    for jj, j in enumerate(candidate_idx):
        valid = dmd1_valid[i] & dmd2_valid[j]
        score[ii, jj] = ncc(dmd1_prep[i], dmd2_prep[j], valid)

# Plot DMD1 z vs DMD2 z similarity.
fig, ax = plt.subplots(figsize=(7, 6))
im = ax.imshow(
    score,
    origin="lower",
    aspect="auto",
    extent=[
        z_um[candidate_idx[0]],
        z_um[candidate_idx[-1]],
        z_um[candidate_idx[0]],
        z_um[candidate_idx[-1]],
    ],
)
ax.plot(
    [z_um[candidate_idx[0]], z_um[candidate_idx[-1]]],
    [z_um[candidate_idx[0]], z_um[candidate_idx[-1]]],
    "w--",
    lw=1,
    label="no z offset",
)
ax.set_xlabel("DMD2 z, um")
ax.set_ylabel("DMD1 z, um")
ax.set_title("DMD1-vs-DMD2 z similarity after XY correction")
ax.legend(loc="upper left")
plt.colorbar(im, ax=ax, label="normalized cross-correlation")
plt.tight_layout()

# Estimate best integer lag.
lags = np.arange(-10, 11)
lag_scores = []

for lag in lags:
    vals = []
    for i in candidate_idx:
        j = i + lag
        if j in dmd2_prep:
            ii = np.where(candidate_idx == i)[0][0]
            jj = np.where(candidate_idx == j)[0][0]
            if np.isfinite(score[ii, jj]):
                vals.append(score[ii, jj])
    lag_scores.append(np.nanmedian(vals) if vals else np.nan)

lag_scores = np.asarray(lag_scores)
best_lag = int(lags[np.nanargmax(lag_scores)])
recommended_dmd2_z_offset_um = -best_lag * dz

fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(lags, lag_scores, marker="o")
ax.axvline(best_lag, linestyle="--")
ax.set_xlabel("DMD2 index - DMD1 index, planes")
ax.set_ylabel("median overlap similarity")
ax.set_title(
    f"Best lag = {best_lag:+d} planes; "
    f"recommended DMD2 z offset = {recommended_dmd2_z_offset_um:+.2f} um"
)
plt.tight_layout()

print(f"Best lag: {best_lag:+d} planes")
print(f"Recommended DMD2 z offset: {recommended_dmd2_z_offset_um:+.3f} um")
# Out:
# candidate planes:
# Fiji plane 083, zero-index 082, z = -76.875 um
# Fiji plane 084, zero-index 083, z = -75.375 um
# Fiji plane 085, zero-index 084, z = -73.875 um
# Fiji plane 086, zero-index 085, z = -72.375 um
# Fiji plane 087, zero-index 086, z = -70.875 um
# Fiji plane 088, zero-index 087, z = -69.375 um
# Fiji plane 089, zero-index 088, z = -67.875 um
# Fiji plane 090, zero-index 089, z = -66.375 um
# Fiji plane 091, zero-index 090, z = -64.875 um
# Fiji plane 092, zero-index 091, z = -63.375 um
# Fiji plane 093, zero-index 092, z = -61.875 um
# Fiji plane 094, zero-index 093, z = -60.375 um
# Fiji plane 095, zero-index 094, z = -58.875 um
# Fiji plane 096, zero-index 095, z = -57.375 um
# Fiji plane 097, zero-index 096, z = -55.875 um
# Fiji plane 098, zero-index 097, z = -54.375 um
# Fiji plane 099, zero-index 098, z = -52.875 um
# Fiji plane 100, zero-index 099, z = -51.375 um
# Fiji plane 101, zero-index 100, z = -49.875 um
# Fiji plane 102, zero-index 101, z = -48.375 um
# Fiji plane 103, zero-index 102, z = -46.875 um
# Fiji plane 104, zero-index 103, z = -45.375 um
# Fiji plane 105, zero-index 104, z = -43.875 um
# Fiji plane 106, zero-index 105, z = -42.375 um
# Fiji plane 107, zero-index 106, z = -40.875 um
# Fiji plane 108, zero-index 107, z = -39.375 um
# Fiji plane 109, zero-index 108, z = -37.875 um
# Fiji plane 110, zero-index 109, z = -36.375 um
# Fiji plane 111, zero-index 110, z = -34.875 um
# Fiji plane 112, zero-index 111, z = -33.375 um
# Fiji plane 113, zero-index 112, z = -31.875 um
# Best lag: +5 planes
# Recommended DMD2 z offset: -7.500 um

# %% [markdown]
# ## CLI equivalents
#
# Full reference stack footprint QC:
#
# ```bash
# slap2-align slap2-footprints DMD1-REFERENCE.tif DMD2-REFERENCE.tif out_dir
# ```
#
# Full reference stack merge:
#
# ```bash
# slap2-align slap2-merge-dmds DMD1-REFERENCE.tif DMD2-REFERENCE.tif out_dir \
#   --xy-resolution-um 0.25 \
#   --z-resolution-um 1.5 \
#   --fine-register-overlap
# ```
#
# Use the notebook path for Fiji substacks, because the substack metadata must be manually reconstructed.
